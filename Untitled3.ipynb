# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathvik9122/Movie-Recommendation-System/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque
import heapq

# ------------------ Graph ------------------
graph = {
    "A": ["B", "C"],
    "B": ["D"],
    "C": ["D"],
    "D": ["G"],
    "G": []
}

weighted_graph = {
    "A": [("B", 1), ("C", 5)],
    "B": [("D", 1)],
    "C": [("D", 1)],
    "D": [("G", 1)],
    "G": []
}

# ------------------ BFS ------------------
def bfs(graph, start, goal):
    queue = deque([[start]])
    visited = set()

    while queue:
        path = queue.popleft()
        node = path[-1]

        if node == goal:
            return path

        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append(path + [neighbor])

# ------------------ DFS ------------------
def dfs(graph, start, goal):
    stack = [[start]]
    visited = set()

    while stack:
        path = stack.pop()
        node = path[-1]

        if node == goal:
            return path

        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                stack.append(path + [neighbor])

# ------------------ Uniform Cost Search ------------------
def ucs(graph, start, goal):
    pq = [(0, start, [start])]
    visited = set()

    while pq:
        cost, node, path = heapq.heappop(pq)

        if node == goal:
            return cost, path

        if node not in visited:
            visited.add(node)
            for neighbor, weight in graph[node]:
                heapq.heappush(pq, (cost + weight, neighbor, path + [neighbor]))

# ------------------ Run ------------------
print("="*45)
print("      ARTIFICIAL INTELLIGENCE PRACTICAL")
print("      BFS | DFS | Uniform Cost Search")
print("="*45)

bfs_path = bfs(graph, "A", "G")
dfs_path = dfs(graph, "A", "G")
cost, ucs_path = ucs(weighted_graph, "A", "G")

print("\nBFS Path :", " -> ".join(bfs_path))
print("DFS Path :", " -> ".join(dfs_path))
print("UCS Path :", " -> ".join(ucs_path))
print("Total Cost:", cost)

print("\nComparison")
print("-"*45)
print("BFS : Uses Queue (FIFO) and finds shortest path.")
print("DFS : Uses Stack (LIFO) and explores deep first.")
print("UCS : Uses Priority Queue and finds minimum cost path.")
# Out:
# ...
#       ARTIFICIAL INTELLIGENCE PRACTICAL
#       BFS | DFS | Uniform Cost Search
# ...
#
# BFS Path : A -> B -> D -> G
# DFS Path : A -> C -> D -> G
# UCS Path : A -> B -> D -> G
# Total Cost: 3
#
# Comparison
# ---------------------------------------------
# BFS : Uses Queue (FIFO) and finds shortest path.
# DFS : Uses Stack (LIFO) and explores deep first.
# UCS : Uses Priority Queue and finds minimum cost path.
